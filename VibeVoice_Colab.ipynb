# %% [markdown]
# # VibeVoice Colab
# ### 🏷️ **Credits & License**
#
# * 🔗 [VibeVoice GitHub Repository](https://github.com/microsoft/VibeVoice)
# * 🤗 [VibeVoice on Hugging Face](https://huggingface.co/microsoft/VibeVoice-1.5B)
# * 📄 **License**: Provided under the [MIT License](https://github.com/microsoft/VibeVoice/blob/main/LICENSE)
#
# ### ⚠️ **Usage Disclaimer**
#
# This tool enables **AI-generated podcast creation** using cloned voices. While it can be a powerful resource for storytelling, education, and creative projects, it also carries risks if misused. By using this tool, you agree to the following guidelines:
#
# * **No Misrepresentation**: Do not use cloned voices to impersonate real people or mislead listeners into believing AI-generated voices are authentic recordings without disclosure.
# * **Transparency**: Clearly disclose when podcast content has been generated with AI, including synthetic voices or AI-written scripts.
# * **No Harmful Content**: Do not produce or distribute content that promotes hate, harassment, misinformation, defamation, or any form of harmful/deceptive material.
# * **Legal Compliance**: Ensure all use of this tool complies with copyright laws, data protection regulations, and all applicable legal and ethical standards.
# * **Respect for Consent**: Do not replicate or publish anyone’s voice without explicit permission.
#
# > ⚖️ **Legal Responsibility**
#
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
# @title Install VibeVoice

# %cd /content/


# !git clone https://github.com/microsoft/VibeVoice.git
# Download colab.py
# %cd /content/VibeVoice/demo
# !wget https://raw.githubusercontent.com/NeuralFalconYT/VibeVoice/refs/heads/main/demo/colab.py


# (Optional) If you experience compatibility issues with the latest version, you can use a pinned fork instead:
# !git clone https://github.com/NeuralFalconYT/VibeVoice.git



# %cd /content/VibeVoice/
# !pip install -e .
# !pip install pydub>=0.25.1

from IPython.display import clear_output
clear_output()

# %%
#@title Run Official Gradio UI
# !python /content/VibeVoice/demo/gradio_demo.py --model_path "microsoft/VibeVoice-1.5B" --inference_steps 10 --share

# %%
#@title Automatically save podcast to your Google Drive [Optional]
Enable_Drive_Save= False  # @param {type: "boolean"}
if Enable_Drive_Save:
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
#@title Run VibeVoice Podcast
# !python /content/VibeVoice/demo/colab.py --model_path microsoft/VibeVoice-1.5B --inference_steps 10 --debug --share
# Out:
# 2026-03-26 20:08:03.641587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774555683.661508   17321 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774555683.668747   17321 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774555683.688006   17321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774555683.688030   17321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774555683.688034   17321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774555683.688038   17321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-26 20:08:03.692999: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# 📂 Download directory: /content/VibeVoice/VibeVoice-1.5B
# 📦 Found 9 files in repo 'microsoft/VibeVoice-1.5B'. Checking cache ...
# Processing files:   0% 0/9 [00:00<?, ?file/s]
# .gitattributes:   0% 0.00/1.57k [00:00<?, ?B/s]
# .gitattributes: 16.0kB [00:00, 122kB/s]
# ⬇️ Downloaded: .gitattributes
# Processing files:  11% 1/9 [00:00<00:02,  3.33file/s]
# README.md:   0% 0.00/7.11k [00:00<?, ?B/s]
# README.md: 16.0kB [00:00, 119kB/s]
# ⬇️ Downloaded: README.md
# Processing files:  22% 2/9 [00:00<00:02,  2.70file/s]
# config.json:   0% 0.00/2.70k [00:00<?, ?B/s]
# config.json: 16.0kB [00:00, 112kB/s]
# ⬇️ Downloaded: config.json
# Processing files:  33% 3/9 [00:01<00:02,  2.98file/s]
# Fig1.png:   0% 0.00/150k [00:00<?, ?B/s]
# Fig1.png: 160kB [00:00, 1.05MB/s]
# ⬇️ Downloaded: Fig1.png
# Processing files:  44% 4/9 [00:01<00:01,  3.04file/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.84G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 8.00k/1.84G [00:00<9:49:08, 55.9kB/s]
# model-00001-of-00003.safetensors:   1% 17.6M/1.84G [00:00<00:21, 90.9MB/s]
# model-00001-of-00003.safetensors:   3% 52.5M/1.84G [00:00<00:09, 205MB/s]
# model-00001-of-00003.safetensors:   5% 86.3M/1.84G [00:00<00:07, 260MB/s]
# model-00001-of-00003.safetensors:   6% 119M/1.84G [00:00<00:06, 288MB/s]
# model-00001-of-00003.safetensors:   8% 151M/1.84G [00:00<00:05, 303MB/s]
# model-00001-of-00003.safetensors:  10% 180M/1.84G [00:00<00:06, 282MB/s]
# model-00001-of-00003.safetensors:  11% 208M/1.84G [00:00<00:06, 286MB/s]
# model-00001-of-00003.safetensors:  13% 241M/1.84G [00:00<00:05, 303MB/s]
# model-00001-of-00003.safetensors:  14% 272M/1.84G [00:01<00:05, 309MB/s]
# model-00001-of-00003.safetensors:  16% 302M/1.84G [00:01<00:05, 294MB/s]
# model-00001-of-00003.safetensors:  18% 330M/1.84G [00:01<00:05, 277MB/s]
# model-00001-of-00003.safetensors:  19% 357M/1.84G [00:01<00:05, 274MB/s]
# model-00001-of-00003.safetensors:  20% 383M/1.84G [00:01<00:05, 264MB/s]
# model-00001-of-00003.safetensors:  22% 412M/1.84G [00:01<00:05, 275MB/s]
# model-00001-of-00003.safetensors:  23% 442M/1.84G [00:01<00:05, 286MB/s]
# model-00001-of-00003.safetensors:  25% 469M/1.84G [00:01<00:05, 254MB/s]
# model-00001-of-00003.safetensors:  26% 494M/1.84G [00:01<00:05, 250MB/s]
# model-00001-of-00003.safetensors:  28% 519M/1.84G [00:02<00:05, 247MB/s]
# model-00001-of-00003.safetensors:  29% 543M/1.84G [00:02<00:05, 246MB/s]
# model-00001-of-00003.safetensors:  30% 566M/1.84G [00:02<00:06, 228MB/s]
# model-00001-of-00003.safetensors:  31% 592M/1.84G [00:02<00:05, 240MB/s]
# model-00001-of-00003.safetensors:  33% 621M/1.84G [00:02<00:05, 257MB/s]
# model-00001-of-00003.safetensors:  34% 646M/1.84G [00:03<00:16, 78.8MB/s]
# model-00001-of-00003.safetensors:  36% 677M/1.84G [00:03<00:11, 106MB/s]
# model-00001-of-00003.safetensors:  37% 699M/1.84G [00:03<00:10, 123MB/s]
# model-00001-of-00003.safetensors:  39% 727M/1.84G [00:03<00:08, 150MB/s]
# model-00001-of-00003.safetensors:  40% 750M/1.84G [00:03<00:07, 160MB/s]
# model-00001-of-00003.safetensors:  41% 779M/1.84G [00:03<00:06, 189MB/s]
# model-00001-of-00003.safetensors:  43% 803M/1.84G [00:04<00:05, 197MB/s]
# model-00001-of-00003.safetensors:  44% 828M/1.84G [00:04<00:05, 212MB/s]
# model-00001-of-00003.safetensors:  45% 851M/1.84G [00:04<00:05, 200MB/s]
# model-00001-of-00003.safetensors:  46% 875M/1.84G [00:04<00:04, 212MB/s]
# model-00001-of-00003.safetensors:  48% 904M/1.84G [00:04<00:04, 235MB/s]
# model-00001-of-00003.safetensors:  49% 928M/1.84G [00:06<00:28, 34.9MB/s]
# model-00001-of-00003.safetensors:  50% 945M/1.84G [00:06<00:23, 42.7MB/s]
# model-00001-of-00003.safetensors:  51% 970M/1.84G [00:06<00:16, 57.8MB/s]
# model-00001-of-00003.safetensors:  53% 0.98G/1.84G [00:07<00:11, 83.0MB/s]
# model-00001-of-00003.safetensors:  55% 1.01G/1.84G [00:07<00:07, 112MB/s]
# model-00001-of-00003.safetensors:  56% 1.03G/1.84G [00:07<00:08, 107MB/s]
# model-00001-of-00003.safetensors:  57% 1.06G/1.84G [00:07<00:06, 126MB/s]
# model-00001-of-00003.safetensors:  59% 1.08G/1.84G [00:07<00:05, 149MB/s]
# model-00001-of-00003.safetensors:  60% 1.10G/1.84G [00:07<00:04, 162MB/s]
# model-00001-of-00003.safetensors:  61% 1.12G/1.84G [00:07<00:04, 174MB/s]
# model-00001-of-00003.safetensors:  62% 1.15G/1.84G [00:07<00:03, 187MB/s]
# model-00001-of-00003.safetensors:  64% 1.17G/1.84G [00:08<00:03, 203MB/s]
# model-00001-of-00003.safetensors:  65% 1.19G/1.84G [00:08<00:03, 221MB/s]
# model-00001-of-00003.safetensors:  66% 1.22G/1.84G [00:08<00:02, 231MB/s]
# model-00001-of-00003.safetensors:  68% 1.24G/1.84G [00:08<00:02, 234MB/s]
# model-00001-of-00003.safetensors:  69% 1.27G/1.84G [00:08<00:02, 251MB/s]
# model-00001-of-00003.safetensors:  71% 1.30G/1.84G [00:08<00:02, 267MB/s]
# model-00001-of-00003.safetensors:  72% 1.32G/1.84G [00:08<00:02, 252MB/s]
# model-00001-of-00003.safetensors:  73% 1.35G/1.84G [00:08<00:02, 255MB/s]
# model-00001-of-00003.safetensors:  75% 1.37G/1.84G [00:08<00:01, 253MB/s]
# model-00001-of-00003.safetensors:  76% 1.40G/1.84G [00:09<00:01, 250MB/s]
# model-00001-of-00003.safetensors:  77% 1.42G/1.84G [00:09<00:01, 245MB/s]
# model-00001-of-00003.safetensors:  78% 1.44G/1.84G [00:09<00:01, 246MB/s]
# model-00001-of-00003.safetensors:  80% 1.47G/1.84G [00:09<00:01, 244MB/s]
# model-00001-of-00003.safetensors:  81% 1.49G/1.84G [00:09<00:01, 241MB/s]
# model-00001-of-00003.safetensors:  82% 1.51G/1.84G [00:09<00:01, 237MB/s]
# model-00001-of-00003.safetensors:  83% 1.53G/1.84G [00:09<00:01, 238MB/s]
# model-00001-of-00003.safetensors:  85% 1.56G/1.84G [00:09<00:01, 247MB/s]
# model-00001-of-00003.safetensors:  86% 1.58G/1.84G [00:09<00:01, 249MB/s]
# model-00001-of-00003.safetensors:  87% 1.61G/1.84G [00:09<00:01, 249MB/s]
# model-00001-of-00003.safetensors:  89% 1.63G/1.84G [00:10<00:00, 260MB/s]
# model-00001-of-00003.safetensors:  90% 1.66G/1.84G [00:10<00:00, 251MB/s]
# model-00001-of-00003.safetensors:  91% 1.68G/1.84G [00:10<00:00, 240MB/s]
# model-00001-of-00003.safetensors:  93% 1.71G/1.84G [00:10<00:00, 247MB/s]
# model-00001-of-00003.safetensors:  95% 1.74G/1.84G [00:10<00:00, 281MB/s]
# model-00001-of-00003.safetensors:  96% 1.77G/1.84G [00:10<00:00, 289MB/s]
# model-00001-of-00003.safetensors:  98% 1.80G/1.84G [00:10<00:00, 301MB/s]
# model-00001-of-00003.safetensors: 1.84GB [00:10, 183MB/s]
# ⬇️ Downloaded: model-00001-of-00003.safetensors
# Processing files:  56% 5/9 [00:12<00:16,  4.16s/file]
# model-00002-of-00003.safetensors:   0% 0.00/1.85G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 8.00k/1.85G [00:00<10:03:15, 54.8kB/s]
# model-00002-of-00003.safetensors:   1% 15.3M/1.85G [00:00<00:25, 78.0MB/s]
# model-00002-of-00003.safetensors:   2% 45.2M/1.85G [00:00<00:11, 174MB/s]
# model-00002-of-00003.safetensors:   4% 76.7M/1.85G [00:00<00:08, 232MB/s]
# model-00002-of-00003.safetensors:   6% 110M/1.85G [00:00<00:06, 271MB/s]
# model-00002-of-00003.safetensors:   7% 139M/1.85G [00:00<00:06, 283MB/s]
# model-00002-of-00003.safetensors:   9% 169M/1.85G [00:00<00:06, 294MB/s]
# model-00002-of-00003.safetensors:  11% 201M/1.85G [00:00<00:05, 307MB/s]
# model-00002-of-00003.safetensors:  12% 235M/1.85G [00:00<00:05, 322MB/s]
# model-00002-of-00003.safetensors:  14% 266M/1.85G [00:01<00:05, 323MB/s]
# model-00002-of-00003.safetensors:  16% 299M/1.85G [00:01<00:05, 329MB/s]
# model-00002-of-00003.safetensors:  17% 330M/1.85G [00:01<00:04, 329MB/s]
# model-00002-of-00003.safetensors:  19% 362M/1.85G [00:01<00:05, 319MB/s]
# model-00002-of-00003.safetensors:  21% 393M/1.85G [00:01<00:04, 320MB/s]
# model-00002-of-00003.safetensors:  22% 424M/1.85G [00:01<00:04, 322MB/s]
# model-00002-of-00003.safetensors:  24% 456M/1.85G [00:01<00:04, 325MB/s]
# model-00002-of-00003.safetensors:  26% 487M/1.85G [00:01<00:04, 318MB/s]
# model-00002-of-00003.safetensors:  27% 518M/1.85G [00:01<00:04, 322MB/s]
# model-00002-of-00003.safetensors:  29% 549M/1.85G [00:01<00:04, 309MB/s]
# model-00002-of-00003.safetensors:  31% 579M/1.85G [00:02<00:04, 302MB/s]
# model-00002-of-00003.safetensors:  32% 610M/1.85G [00:02<00:04, 309MB/s]
# model-00002-of-00003.safetensors:  34% 640M/1.85G [00:02<00:04, 306MB/s]
# model-00002-of-00003.safetensors:  35% 669M/1.85G [00:02<00:04, 283MB/s]
# model-00002-of-00003.safetensors:  37% 696M/1.85G [00:02<00:04, 273MB/s]
# model-00002-of-00003.safetensors:  38% 722M/1.85G [00:02<00:04, 264MB/s]
# model-00002-of-00003.safetensors:  40% 748M/1.85G [00:02<00:04, 251MB/s]
# model-00002-of-00003.safetensors:  41% 772M/1.85G [00:02<00:04, 252MB/s]
# model-00002-of-00003.safetensors:  42% 800M/1.85G [00:02<00:04, 263MB/s]
# model-00002-of-00003.safetensors:  44% 825M/1.85G [00:03<00:04, 257MB/s]
# model-00002-of-00003.safetensors:  45% 854M/1.85G [00:03<00:04, 270MB/s]
# model-00002-of-00003.safetensors:  47% 880M/1.85G [00:03<00:04, 262MB/s]
# model-00002-of-00003.safetensors:  48% 905M/1.85G [00:03<00:04, 246MB/s]
# model-00002-of-00003.safetensors:  49% 931M/1.85G [00:03<00:03, 254MB/s]
# model-00002-of-00003.safetensors:  51% 957M/1.85G [00:03<00:03, 259MB/s]
# model-00002-of-00003.safetensors:  52% 982M/1.85G [00:03<00:03, 255MB/s]
# model-00002-of-00003.safetensors:  53% 0.98G/1.85G [00:05<00:25, 36.2MB/s]
# model-00002-of-00003.safetensors:  54% 1.00G/1.85G [00:06<00:19, 46.6MB/s]
# model-00002-of-00003.safetensors:  56% 1.04G/1.85G [00:06<00:12, 67.6MB/s]
# model-00002-of-00003.safetensors:  58% 1.07G/1.85G [00:06<00:08, 94.9MB/s]
# model-00002-of-00003.safetensors:  59% 1.10G/1.85G [00:06<00:06, 118MB/s]
# model-00002-of-00003.safetensors:  61% 1.12G/1.85G [00:06<00:05, 144MB/s]
# model-00002-of-00003.safetensors:  62% 1.15G/1.85G [00:06<00:04, 160MB/s]
# model-00002-of-00003.safetensors:  64% 1.17G/1.85G [00:06<00:04, 176MB/s]
# model-00002-of-00003.safetensors:  65% 1.20G/1.85G [00:06<00:03, 203MB/s]
# model-00002-of-00003.safetensors:  67% 1.23G/1.85G [00:06<00:02, 230MB/s]
# model-00002-of-00003.safetensors:  68% 1.26G/1.85G [00:06<00:02, 250MB/s]
# model-00002-of-00003.safetensors:  70% 1.29G/1.85G [00:07<00:02, 262MB/s]
# model-00002-of-00003.safetensors:  71% 1.32G/1.85G [00:07<00:02, 281MB/s]
# model-00002-of-00003.safetensors:  73% 1.35G/1.85G [00:07<00:01, 291MB/s]
# model-00002-of-00003.safetensors:  75% 1.38G/1.85G [00:07<00:01, 295MB/s]
# model-00002-of-00003.safetensors:  76% 1.41G/1.85G [00:07<00:01, 304MB/s]
# model-00002-of-00003.safetensors:  78% 1.44G/1.85G [00:07<00:01, 298MB/s]
# model-00002-of-00003.safetensors:  80% 1.47G/1.85G [00:07<00:01, 312MB/s]
# model-00002-of-00003.safetensors:  81% 1.50G/1.85G [00:07<00:01, 287MB/s]
# model-00002-of-00003.safetensors:  83% 1.53G/1.85G [00:07<00:01, 286MB/s]
# model-00002-of-00003.safetensors:  84% 1.56G/1.85G [00:08<00:01, 296MB/s]
# model-00002-of-00003.safetensors:  86% 1.59G/1.85G [00:08<00:00, 298MB/s]
# model-00002-of-00003.safetensors:  87% 1.61G/1.85G [00:08<00:00, 301MB/s]
# model-00002-of-00003.safetensors:  89% 1.64G/1.85G [00:08<00:00, 282MB/s]
# model-00002-of-00003.safetensors:  90% 1.67G/1.85G [00:08<00:00, 282MB/s]
# model-00002-of-00003.safetensors:  92% 1.70G/1.85G [00:08<00:00, 278MB/s]
# model-00002-of-00003.safetensors:  93% 1.72G/1.85G [00:08<00:00, 267MB/s]
# model-00002-of-00003.safetensors:  95% 1.75G/1.85G [00:08<00:00, 258MB/s]
# model-00002-of-00003.safetensors:  96% 1.77G/1.85G [00:08<00:00, 257MB/s]
# model-00002-of-00003.safetensors:  97% 1.79G/1.85G [00:08<00:00, 255MB/s]
# model-00002-of-00003.safetensors:  98% 1.82G/1.85G [00:09<00:00, 254MB/s]
# model-00002-of-00003.safetensors: 1.85GB [00:09, 215MB/s]
# ⬇️ Downloaded: model-00002-of-00003.safetensors
# Processing files:  67% 6/9 [00:21<00:17,  5.93s/file]
# model-00003-of-00003.safetensors:   0% 0.00/1.35G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 8.00k/1.35G [00:00<8:12:34, 49.1kB/s]
# model-00003-of-00003.safetensors:   1% 10.3M/1.35G [00:00<00:28, 49.7MB/s]
# model-00003-of-00003.safetensors:   2% 31.6M/1.35G [00:00<00:11, 119MB/s]
# model-00003-of-00003.safetensors:   4% 53.2M/1.35G [00:00<00:08, 157MB/s]
# model-00003-of-00003.safetensors:   6% 76.1M/1.35G [00:00<00:07, 186MB/s]
# model-00003-of-00003.safetensors:   7% 103M/1.35G [00:00<00:06, 208MB/s]
# model-00003-of-00003.safetensors:   9% 124M/1.35G [00:00<00:08, 164MB/s]
# model-00003-of-00003.safetensors:  11% 147M/1.35G [00:00<00:07, 183MB/s]
# model-00003-of-00003.safetensors:  12% 172M/1.35G [00:01<00:06, 205MB/s]
# model-00003-of-00003.safetensors:  14% 193M/1.35G [00:01<00:06, 204MB/s]
# model-00003-of-00003.safetensors:  16% 216M/1.35G [00:01<00:05, 215MB/s]
# model-00003-of-00003.safetensors:  17% 238M/1.35G [00:01<00:05, 204MB/s]
# model-00003-of-00003.safetensors:  19% 258M/1.35G [00:01<00:05, 207MB/s]
# model-00003-of-00003.safetensors:  21% 284M/1.35G [00:01<00:05, 225MB/s]
# model-00003-of-00003.safetensors:  22% 306M/1.35G [00:01<00:04, 227MB/s]
# model-00003-of-00003.safetensors:  24% 333M/1.35G [00:01<00:04, 243MB/s]
# model-00003-of-00003.safetensors:  26% 357M/1.35G [00:01<00:04, 233MB/s]
# model-00003-of-00003.safetensors:  28% 381M/1.35G [00:02<00:04, 241MB/s]
# model-00003-of-00003.safetensors:  29% 405M/1.35G [00:02<00:04, 242MB/s]
# model-00003-of-00003.safetensors:  31% 431M/1.35G [00:02<00:04, 248MB/s]
# model-00003-of-00003.safetensors:  33% 456M/1.35G [00:02<00:03, 253MB/s]
# model-00003-of-00003.safetensors:  35% 480M/1.35G [00:02<00:03, 250MB/s]
# model-00003-of-00003.safetensors:  36% 504M/1.35G [00:02<00:04, 224MB/s]
# model-00003-of-00003.safetensors:  38% 526M/1.35G [00:02<00:03, 226MB/s]
# model-00003-of-00003.safetensors:  40% 548M/1.35G [00:02<00:03, 220MB/s]
# model-00003-of-00003.safetensors:  41% 573M/1.35G [00:02<00:03, 232MB/s]
# model-00003-of-00003.safetensors:  43% 597M/1.35G [00:02<00:03, 239MB/s]
# model-00003-of-00003.safetensors:  45% 625M/1.35G [00:03<00:03, 252MB/s]
# model-00003-of-00003.safetensors:  47% 649M/1.35G [00:03<00:03, 248MB/s]
# model-00003-of-00003.safetensors:  49% 676M/1.35G [00:03<00:02, 260MB/s]
# model-00003-of-00003.safetensors:  51% 701M/1.35G [00:03<00:02, 260MB/s]
# model-00003-of-00003.safetensors:  53% 726M/1.35G [00:03<00:02, 251MB/s]
# model-00003-of-00003.safetensors:  54% 750M/1.35G [00:03<00:02, 249MB/s]
# model-00003-of-00003.safetensors:  56% 778M/1.35G [00:03<00:02, 259MB/s]
# model-00003-of-00003.safetensors:  58% 806M/1.35G [00:03<00:02, 269MB/s]
# model-00003-of-00003.safetensors:  60% 835M/1.35G [00:03<00:02, 280MB/s]
# model-00003-of-00003.safetensors:  62% 862M/1.35G [00:04<00:01, 279MB/s]
# model-00003-of-00003.safetensors:  65% 892M/1.35G [00:04<00:01, 290MB/s]
# model-00003-of-00003.safetensors:  67% 921M/1.35G [00:04<00:01, 295MB/s]
# model-00003-of-00003.safetensors:  69% 951M/1.35G [00:04<00:01, 299MB/s]
# model-00003-of-00003.safetensors:  71% 979M/1.35G [00:04<00:01, 293MB/s]
# model-00003-of-00003.safetensors:  73% 0.98G/1.35G [00:04<00:01, 287MB/s]
# model-00003-of-00003.safetensors:  75% 1.01G/1.35G [00:04<00:01, 297MB/s]
# model-00003-of-00003.safetensors:  77% 1.04G/1.35G [00:04<00:01, 281MB/s]
# model-00003-of-00003.safetensors:  79% 1.07G/1.35G [00:04<00:01, 294MB/s]
# model-00003-of-00003.safetensors:  81% 1.10G/1.35G [00:04<00:00, 295MB/s]
# model-00003-of-00003.safetensors:  84% 1.13G/1.35G [00:05<00:00, 302MB/s]
# model-00003-of-00003.safetensors:  86% 1.16G/1.35G [00:05<00:00, 301MB/s]
# model-00003-of-00003.safetensors:  88% 1.19G/1.35G [00:05<00:00, 310MB/s]
# model-00003-of-00003.safetensors:  90% 1.22G/1.35G [00:05<00:00, 272MB/s]
# model-00003-of-00003.safetensors:  92% 1.24G/1.35G [00:05<00:00, 252MB/s]
# model-00003-of-00003.safetensors:  94% 1.27G/1.35G [00:05<00:00, 253MB/s]
# model-00003-of-00003.safetensors:  96% 1.29G/1.35G [00:05<00:00, 256MB/s]
# model-00003-of-00003.safetensors: 1.35GB [00:05, 244MB/s]
# ⬇️ Downloaded: model-00003-of-00003.safetensors
# Processing files:  78% 7/9 [00:27<00:11,  5.99s/file]
# model.safetensors.index.json:   0% 0.00/120k [00:00<?, ?B/s]
# model.safetensors.index.json: 128kB [00:00, 831kB/s]
# ⬇️ Downloaded: model.safetensors.index.json
# Processing files:  89% 8/9 [00:28<00:04,  4.20s/file]
# preprocessor_config.json:   0% 0.00/351 [00:00<?, ?B/s]
# preprocessor_config.json: 16.0kB [00:00, 118kB/s]
# ⬇️ Downloaded: preprocessor_config.json
# Processing files: 100% 9/9 [00:28<00:00,  3.16s/file]
# 🎙️ Initializing VibeVoice ...
# Loading processor & model from /content/VibeVoice/VibeVoice-1.5B
# tokenizer_config.json: 7.23kB [00:00, 27.8MB/s]
# vocab.json: 2.78MB [00:00, 78.8MB/s]
# merges.txt: 1.67MB [00:00, 151MB/s]
# tokenizer.json: 7.03MB [00:00, 192MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Loading checkpoint shards: 100% 3/3 [00:21<00:00,  7.29s/it]
# Language model attention: sdpa
# Found 9 voice files in /content/VibeVoice/demo/voices
# 🚀 Launching Gradio Demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://dbaabe653ab6f60e37.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Found 10 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/at_nvidias_gtc_2026_event_je_7f5f5b.wav
# 📄 Timestamps: ./podcast_audio/at_nvidias_gtc_2026_event_je_7f5f5b.json
#
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/at_nvidias_gtc_2026_event_je_b22548.wav
# 📄 Timestamps: ./podcast_audio/at_nvidias_gtc_2026_event_je_b22548.json
#
# Found 11 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/at_nvidias_gtc_2026_event_je_37cdb5.wav
# 📄 Timestamps: ./podcast_audio/at_nvidias_gtc_2026_event_je_37cdb5.json
#
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/at_nvidias_gtc_2026_event_je_47e976.wav
# 📄 Timestamps: ./podcast_audio/at_nvidias_gtc_2026_event_je_47e976.json
#
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/people_were_excited_of_course_e5b9fe.wav
# 📄 Timestamps: ./podcast_audio/people_were_excited_of_course_e5b9fe.json
